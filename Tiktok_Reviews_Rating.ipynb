# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("tiktok_google_play_reviews.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325767 entries, 0 to 325766
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              325767 non-null  object
#  1   userName              325767 non-null  object
#  2   userImage             325767 non-null  object
#  3   content               325755 non-null  object
#  4   score                 325766 non-null  float64
#  5   thumbsUpCount         325766 non-null  float64
#  6   reviewCreatedVersion  235990 non-null  object
#  7   at                    325766 non-null  object
#  8   replyContent          218 non-null     object
#  9   repliedAt             218 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 24.9+ MB

# %%
data.head()
# Out:
#                                reviewId              userName  \
# 0  68ccaec8-1415-4301-a85e-3004679a3a83          Cassie Moore
# 1  d84cbfd3-6aa3-485c-aaf9-c5dca27dc966         Kaleb Plummer
# 2  96618aa1-31e5-4259-8649-89b75d962f00           Rylee Maher
# 3  078c0bda-598b-474e-a04e-d7cb3e6f6301  Kittykatelyn Romilly
# 4  8e68c5cd-b12a-4206-a8da-6bfdbff44ae3      Loveness Malenga
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ALm5wu...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0                                           No words    5.0            0.0
# 1                              Great fun app so far!    5.0            0.0
# ...

# %% [markdown]
# **TikTok reviews sentiment analysis**

# %%
data[['content', 'score']]
# Out:
#                                                   content  score
# 0                                                No words    5.0
# 1                                   Great fun app so far!    5.0
# 2       The app would get a higher rating but I litera...    1.0
# 3       I WISH I COULD GIVE THIS A 100 PERCENT RATING ...    5.0
# 4                                     Pictures and record    5.0
# ...                                                   ...    ...
# 325762                                            Aavshbs    1.0
# 325763  Overall the app is good but fix ur translation...    3.0
# 325764  Literally Chinese Spyware no idea how this bec...    1.0
# 325765                                             I lpve    5.0
# 325766                                            Nice ap    NaN
#
# [325767 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# reviewId                     0
# userName                     0
# userImage                    0
# content                     12
# score                        1
# thumbsUpCount                1
# reviewCreatedVersion     89777
# at                           1
# replyContent            325549
# repliedAt               325549
# dtype: int64

# %%
data.dropna()
# Out:
#                                     reviewId            userName  \
# 5095    f8752692-abb5-46a7-bf9c-b7a45f597f49           Kiki Bell
# 5322    b2859354-1a1c-44db-9ea1-2d37f453fd1b   Cheryl Czerwinski
# 7187    ab272bcd-8721-41e7-841f-55d0c4c53349      MuffinGuns9846
# 8720    ab934db2-96e5-4c18-8284-b8bcfc9b94eb     Lamatronic vogs
# 10801   6a5bfb43-d1b1-4031-814f-520f902e7917       A Google user
# ...                                      ...                 ...
# 306266  ce317664-0335-4beb-8350-348572969684           Blue Nova
# 312370  f9cf91bf-c39a-4f06-bf5e-405d83cf2353  charlotte oliveira
# 321285  a10cf1aa-70c9-4e81-bbf1-9b733192b2bc     Aneisha Briscoe
# 324639  14118c0c-1dd5-4ab2-b4ab-cab84adc1037            ahil god
# 324653  611d1b75-29a1-47f7-911d-8c7db31e383d           Reiha Ali
#
#                                                 userImage  \
# 5095    https://play-lh.googleusercontent.com/a/ALm5wu...
# 5322    https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.corpus import stopwords
import re
import string
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopword=set(stopwords.words('english'))
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data['content'] = data['content'].apply(clean)

# %%
ratings = data["score"].value_counts()
numbers = ratings.index
quantity = ratings.values

# %%
import plotly.express as px

# %% [markdown]
# **Visualization percentages of ratings given to TikTok on the Google Play store**

# %%
figure = px.pie(data, values=quantity, names=numbers,hole = 0.5)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
